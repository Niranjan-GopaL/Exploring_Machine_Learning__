# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('q_2.csv')
df.head(5)
# Out:
#            time  V(vin)        Ig(M1)
# 0  0.000000e+00    -1.0 -5.400000e-07
# 1  1.950000e-17    -1.0 -4.310000e-07
# 2  3.910000e-17    -1.0 -3.740000e-07
# 3  7.810000e-17    -1.0 -3.380000e-07
# 4  1.560000e-16    -1.0 -3.090000e-07

# %%
plt.plot(df['time'],df['Ig(M1)'],"-o")
plt.grid(True)
plt.xlabel("Vgs(Volt)")
plt.ylabel("Cgs(Farad)")
plt.title("Cgs vs Vgs")
# Out:
# Text(0.5, 1.0, 'Cgs vs Vgs')
